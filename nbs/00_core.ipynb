# %% [markdown]
# # core
#
# > Core description

# %%
#| default_exp core

# %% [markdown]
# Test

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
def foo(): pass

# %%
#| hide
import nbdev; nbdev.nbdev_export()
